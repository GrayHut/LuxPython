# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder.appName('session_one').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/08/12 13:46:09 WARN Utils: Your hostname, anony-threat, resolves to a loopback address: 127.0.1.1; using 192.168.2.104 instead (on interface wlp0s20f3)
# 25/08/12 13:46:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/08/12 13:46:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/08/12 13:46:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/08/12 13:46:10 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.

# %%
print(spark)

# %%
hotel_csv_df=spark.read.csv('hotel_bookings_dirty.csv', header=True, inferSchema=True)
hotel_csv_df.show(3)
# Out:
# +------------+-----------+---------+-----------------+------------------+------------------------+-------------------------+-----------------------+--------------------+------+--------+------+----+-------+--------------+--------------------+-----------------+----------------------+------------------------------+------------------+------------------+---------------+------------+-----+-------+--------------------+-------------+----+---------------------------+-------------------------+------------------+-----------------------+
# ...

# %%
hotel_csv_df.printSchema()
# Out:
# root
#  |-- hotel: string (nullable = true)
#  |-- is_canceled: string (nullable = true)
#  |-- lead_time: string (nullable = true)
#  |-- arrival_date_year: string (nullable = true)
#  |-- arrival_date_month: string (nullable = true)
#  |-- arrival_date_week_number: string (nullable = true)
#  |-- arrival_date_day_of_month: string (nullable = true)
#  |-- stays_in_weekend_nights: string (nullable = true)
#  |-- stays_in_week_nights: string (nullable = true)
#  |-- adults: string (nullable = true)
#  |-- children: string (nullable = true)
#  |-- babies: string (nullable = true)
#  |-- meal: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- market_segment: string (nullable = true)
#  |-- distribution_channel: string (nullable = true)
#  |-- is_repeated_guest: string (nullable = true)
#  |-- previous_cancellations: string (nullable = true)
#  |-- previous_bookings_not_canceled: string (nullable = true)
#  |-- reserved_room_type: string (nullable = true)
# ...
